# %%
x=6
print(id(x))
x+=1
print(id(x))
# Out:
# 10757896
# 10757928

# %%
x=7
address=id(x)
x+=1
print(x)
# Out:
# 8

# %%
lst=[1,2,3]
print(id(lst))
lst.append(4)
print(id(lst))
# Out:
# 135117453828160
# 135117453828160

# %%
lst=[10,20]
print("id before:",id(lst))
lst[0]=99
print("updated list:",lst)
print("id after:",id(lst))
# Out:
# id before: 135117453828032
# updated list: [99, 20]
# id after: 135117453828032

# %%
s=[1,2,3]
print("id before:",id(s))
s.append(4)
print("updated set:",s)
print("id after:",id(s))
# Out:
# id before: 135117453827776
# updated set: [1, 2, 3, 4]
# id after: 135117453827776

# %%
a=10
b=a
print("id of a:",id(a))
print("id of b:",id(b))
b +=1
print("updated b:",b)
print("id of new b:",id(b))
# Out:
# id of a: 10758024
# id of b: 10758024
# updated b: 11
# id of new b: 10758056

# %%
text = "hello"
print("ID before:", id(text))
text = text.upper()
print("Updated text:", text)
print("ID after:", id(text))
# Out:
# ID before: 135118424847152
# Updated text: HELLO
# ID after: 135117453846448

# %%
marks = [80, 90]
print("ID before:", id(marks))
marks.insert(1, 85)
print("Updated list:", marks)
print("ID after:", id(marks))
# Out:
# ID before: 135117453832000
# Updated list: [80, 85, 90]
# ID after: 135117453832000

# %%
colors = {"red", "green"}
print("ID before:", id(colors))
colors.update(["blue"])
print("Updated set:", colors)
print("ID after:", id(colors))
# Out:
# ID before: 135117454026432
# Updated set: {'red', 'blue', 'green'}
# ID after: 135117454026432
